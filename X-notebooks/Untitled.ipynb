# %%
import pandas as pd

# %%
df=pd.read_csv('DOHMH_New_York_City_Restaurant_Inspection_Results.csv')
df.head()
# Out:
#       CAMIS                  DBA       BORO BUILDING            STREET  \
# 0  40385767  ACADEMY RESTAURAUNT   Brooklyn       69  LAFAYETTE AVENUE
# 1  50013059        COCINA TALLER  Manhattan      416        W 203RD ST
# 2  41284555        JIMMY'S DINER   Brooklyn      577      UNION AVENUE
# 3  41605870     CAKOR RESTAURANT      Bronx      632  EAST  186 STREET
# 4  41345907     MEE THAI CUISINE   Brooklyn      180          5 AVENUE
#
#    ZIPCODE       PHONE                                CUISINE DESCRIPTION  \
# 0  11217.0  7182379326                                           American
# 1  10034.0  9174594125  Latin (Cuban, Dominican, Puerto Rican, South &...
# 2  11211.0  7182187174                                           American
# 3  10458.0  7187332300                                   Eastern European
# 4  11217.0  7182308280                                               Thai
#
#   INSPECTION DATE                                           ACTION  ...  \
# ...

# %%
df['INSPECTION DATE']=pd.to_datetime(df['INSPECTION DATE'])

# %%
df.describe()
# Out:
#               CAMIS        ZIPCODE          SCORE       Latitude  \
# count  3.864030e+05  380902.000000  369192.000000  385997.000000
# mean   4.592233e+07   10677.530984      20.129144      40.148467
# std    4.420333e+06     602.435170      14.628687       4.826113
# min    3.007544e+07   10000.000000      -1.000000       0.000000
# 25%    4.137128e+07   10022.000000      11.000000      40.685261
# 50%    5.000270e+07   10468.000000      15.000000      40.732362
# 75%    5.005166e+07   11229.000000      26.000000      40.761817
# max    5.009641e+07   30339.000000     166.000000      40.912822
#
#            Longitude  Community Board  Council District   Census Tract  \
# count  385997.000000    380500.000000     380500.000000  380500.000000
# mean      -72.889989       248.359690         20.008302   28962.169974
# std         8.761321       130.830979         15.818188   30806.213438
# min       -74.248434       101.000000          1.000000     100.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 386403 entries, 0 to 386402
# Data columns (total 26 columns):
# CAMIS                    386403 non-null int64
# DBA                      385827 non-null object
# BORO                     386403 non-null object
# BUILDING                 386165 non-null object
# STREET                   386399 non-null object
# ZIPCODE                  380902 non-null float64
# PHONE                    386388 non-null object
# CUISINE DESCRIPTION      386403 non-null object
# INSPECTION DATE          386403 non-null object
# ACTION                   385015 non-null object
# VIOLATION CODE           380639 non-null object
# VIOLATION DESCRIPTION    377474 non-null object
# CRITICAL FLAG            377474 non-null object
# SCORE                    369192 non-null float64
# GRADE                    196156 non-null object
# GRADE DATE               194303 non-null object
# RECORD DATE              386403 non-null object
# ...

# %%
df['CUISINE DESCRIPTION'].value_counts()
# Out:
# American                                                            82151
# Chinese                                                             40489
# Café/Coffee/Tea                                                     18569
# Pizza                                                               17048
# Latin (Cuban, Dominican, Puerto Rican, South & Central American)    16790
# Italian                                                             15572
# Mexican                                                             15367
# Caribbean                                                           13842
# Japanese                                                            13804
# Spanish                                                             12152
# Bakery                                                              12037
# Pizza/Italian                                                        8392
# Chicken                                                              7099
# ...

# %%
df['CAMIS'].value_counts()
# Out:
# 41187577    84
# 41409441    83
# 40400811    82
# 50036890    82
# 41669112    82
# 50001789    81
# 50035784    81
# 50018552    81
# 41474882    80
# 41683816    79
# 40700664    77
# 41510846    77
# 50009366    76
# 41642333    75
# 41630632    75
# 41451560    72
# 41403222    72
# 50042177    72
# 50016854    71
# 41297769    71
# 41348986    71
# 50056245    71
# 50056438    71
# 50001693    71
# 50002478    71
# 41591603    71
# 50012165    71
# 50012113    70
# 50047362    70
# 50009773    69
#             ..
# 50082148     1
# 50087997     1
# 50090108     1
# 50092256     1
# 50093971     1
# 50079543     1
# 50087906     1
# 50093715     1
# 50080448     1
# 50082146     1
# 50093641     1
# 50083010     1
# 50092137     1
# 50095304     1
# 50089165     1
# 50092824     1
# 50088730     1
# 50095989     1
# 50084950     1
# 50090899     1
# 50095135     1
# 50093775     1
# 50092149     1
# 50092157     1
# 50089677     1
# 50091289     1
# 50091726     1
# ...

# %%
df['CRITICAL FLAG'].value_counts(normalize=True)
# Out:
# Y    0.559514
# N    0.440486
# Name: CRITICAL FLAG, dtype: float64

# %%
df['ACTION'].value_counts(normalize=True)
# Out:
# Violations were cited in the following area(s).                                                                                        0.938486
# Establishment Closed by DOHMH.  Violations were cited in the following area(s) and those requiring immediate action were addressed.    0.036830
# No violations were recorded at the time of this inspection.                                                                            0.011067
# Establishment re-opened by DOHMH                                                                                                       0.010511
# Establishment re-closed by DOHMH                                                                                                       0.003106
# Name: ACTION, dtype: float64

# %%
df['VIOLATION DESCRIPTION'].value_counts()
# Out:
# Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.                      54582
# Facility not vermin proof. Harborage or conditions conducive to attracting vermin to the premises and/or allowing vermin to exist.                                                                                                                                                                   41944
# Evidence of mice or live mice present in facility's food and/or non-food areas.                                                                                                                                                                                                                      28615
# ...

# %%
df.loc[df['VIOLATION CODE']=='10F']['VIOLATION DESCRIPTION'].value_counts()
# Out:
# Non-food contact surface improperly constructed. Unacceptable material used. Non-food contact surface or equipment improperly maintained and/or not properly sealed, raised, spaced or movable to allow accessibility for cleaning on all sides, above and underneath the unit.    54582
# Name: VIOLATION DESCRIPTION, dtype: int64

# %%
df.loc[df['CRITICAL FLAG']=='Y']['VIOLATION CODE'].value_counts()
# Out:
# 04L    28615
# 06D    26587
# 06C    24459
# 02G    22672
# 02B    19886
# 04N    19574
# 04H     8232
# 04M     8146
# 06E     7562
# 06F     7077
# 04A     6996
# 06A     6404
# 02H     5358
# 05D     3548
# 06B     2688
# 04C     2670
# 04K     2618
# 04J     1667
# 05H     1224
# 05F      803
# 03A      662
# 05C      502
# 02C      449
# 02I      429
# 04E      332
# 02A      277
# 04O      250
# 04F      226
# 05E      203
# 03B      187
# 04D      183
# 05A      167
# 06G      135
# 05B      111
# 03C       79
# 02D       55
# 07A       43
# 03E       29
# 02F       20
# 04B       17
# 06H       12
# 03G       12
# 03D       11
# 06I       10
# 03F        5
# 04G        4
# 02E        4
# 02J        1
# 04I        1
# Name: VIOLATION CODE, dtype: int64

# %%
df.loc[df['CRITICAL FLAG']=='N']['VIOLATION CODE'].value_counts()
# Out:
# 10F    54582
# 08A    41944
# 10B    23141
# 09C     6357
# 10H     6302
# 08C     5912
# 09B     4109
# 10I     3891
# 20F     2479
# 10E     2458
# 10J     1813
# 16B     1571
# 10D     1497
# 22C     1402
# 09A     1207
# 20D     1205
# 10A      957
# 15L      910
# 22A      757
# 08B      511
# 20A      499
# 16C      450
# 16D      448
# 16E      414
# 10C      376
# 15I      224
# 16A      147
# 20E      142
# 22E      125
# 18D       92
# 18F       79
# 18G       67
# 10G       63
# 22B       36
# 18C       35
# 15J       18
# 15S       17
# 15K       15
# 18B       13
# 15T        5
# 16F        1
# 20B        1
# Name: VIOLATION CODE, dtype: int64

# %%
df.loc[df['ACTION']=='No violations were recorded at the time of this inspection.']['INSPECTION TYPE'].value_counts()
# Out:
# Administrative Miscellaneous / Initial Inspection              1911
# Cycle Inspection / Initial Inspection                           564
# Administrative Miscellaneous / Re-inspection                    468
# Trans Fat / Initial Inspection                                  332
# Inter-Agency Task Force / Initial Inspection                    198
# Cycle Inspection / Re-inspection                                166
# Pre-permit (Operational) / Initial Inspection                    96
# Trans Fat / Re-inspection                                        92
# Pre-permit (Non-operational) / Initial Inspection                83
# Smoke-Free Air Act / Initial Inspection                          72
# Pre-permit (Operational) / Re-inspection                         56
# Administrative Miscellaneous / Compliance Inspection             51
# Calorie Posting / Initial Inspection                             39
# Trans Fat / Compliance Inspection                                39
# ...

# %%
df.loc[df['ACTION']=='No violations were recorded at the time of this inspection.']['GRADE'].isna().sum()
# Out:
# 3596

# %%
df['RECORD DATE'].value_counts()
# Out:
# 08/05/2019    386403
# Name: RECORD DATE, dtype: int64

# %%
df['DBA'].value_counts()
# Out:
# DUNKIN'                                  3992
# SUBWAY                                   2852
# STARBUCKS                                2121
# MCDONALD'S                               1997
# KENNEDY FRIED CHICKEN                    1291
# DUNKIN', BASKIN ROBBINS                  1137
# CROWN FRIED CHICKEN                      1105
# BURGER KING                               963
# POPEYES                                   957
# DOMINO'S                                  921
# GOLDEN KRUST CARIBBEAN BAKERY & GRILL     852
# CHIPOTLE MEXICAN GRILL                    723
# KFC                                       596
# LE PAIN QUOTIDIEN                         515
# CHECKERS                                  492
# WENDY'S                                   466
# VIVI BUBBLE TEA                           389
# PRET A MANGER                             347
# CARVEL ICE CREAM                          343
# PAPA JOHN'S                               334
# ...

# %%
df['INSPECTION TYPE'].value_counts()
# Out:
# Cycle Inspection / Initial Inspection                          224085
# Cycle Inspection / Re-inspection                                93776
# Pre-permit (Operational) / Initial Inspection                   27070
# Pre-permit (Operational) / Re-inspection                        12135
# Administrative Miscellaneous / Initial Inspection                6927
# Cycle Inspection / Reopening Inspection                          4314
# Pre-permit (Non-operational) / Initial Inspection                3346
# Smoke-Free Air Act / Initial Inspection                          2436
# Administrative Miscellaneous / Re-inspection                     2045
# Trans Fat / Initial Inspection                                   1700
# Pre-permit (Operational) / Compliance Inspection                 1201
# Calorie Posting / Initial Inspection                             1115
# Pre-permit (Operational) / Reopening Inspection                  1048
# ...

# %%
df['CAMIS'].value_counts()
# Out:
# 41187577    84
# 41409441    83
# 40400811    82
# 50036890    82
# 41669112    82
# 50001789    81
# 50035784    81
# 50018552    81
# 41474882    80
# 41683816    79
# 40700664    77
# 41510846    77
# 50009366    76
# 41642333    75
# 41630632    75
# 41451560    72
# 41403222    72
# 50042177    72
# 50016854    71
# 41297769    71
# 41348986    71
# 50056245    71
# 50056438    71
# 50001693    71
# 50002478    71
# 41591603    71
# 50012165    71
# 50012113    70
# 50047362    70
# 50009773    69
#             ..
# 50082148     1
# 50087997     1
# 50090108     1
# 50092256     1
# 50093971     1
# 50079543     1
# 50087906     1
# 50093715     1
# 50080448     1
# 50082146     1
# 50093641     1
# 50083010     1
# 50092137     1
# 50095304     1
# 50089165     1
# 50092824     1
# 50088730     1
# 50095989     1
# 50084950     1
# 50090899     1
# 50095135     1
# 50093775     1
# 50092149     1
# 50092157     1
# 50089677     1
# 50091289     1
# 50091726     1
# ...

# %%
df.loc[df['DBA']=='BUVETTE'][['INSPECTION TYPE',"VIOLATION DESCRIPTION",'SCORE','GRADE','CRITICAL FLAG',"INSPECTION DATE"]].sort_values('INSPECTION DATE')
# Out:
#                               INSPECTION TYPE  \
# 17764   Cycle Inspection / Initial Inspection
# 364916  Cycle Inspection / Initial Inspection
# 268307  Cycle Inspection / Initial Inspection
# 55973   Cycle Inspection / Initial Inspection
# 207133  Cycle Inspection / Initial Inspection
#
#                                     VIOLATION DESCRIPTION  SCORE GRADE  \
# 17764   Food not protected from potential source of co...   10.0     A
# 364916  Sanitized equipment or utensil, including in-u...   10.0     A
# 268307  Non-food contact surface improperly constructe...    2.0     A
# 55973    Food not cooked to required minimum temperature.   12.0     A
# 207133  Non-food contact surface improperly constructe...   12.0     A
#
#        CRITICAL FLAG INSPECTION DATE
# 17764              Y      2017-06-01
# 364916             Y      2017-06-01
# 268307             N      2018-05-29
# 55973              Y      2019-05-15
# 207133             N      2019-05-15

# %%
df.loc[df['CAMIS']==41187577]['INSPECTION DATE'].value_counts()
# Out:
# 2018-06-18    9
# 2019-04-09    9
# 2019-06-12    8
# 2018-11-08    7
# 2017-03-21    6
# 2016-07-13    6
# 2018-08-01    5
# 2018-06-22    5
# 2018-12-04    5
# 2018-01-30    5
# 2016-08-25    4
# 2018-06-26    4
# 2017-04-05    3
# 2018-03-19    3
# 2018-06-29    2
# 2018-10-09    1
# 2018-07-02    1
# 2017-09-13    1
# Name: INSPECTION DATE, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(13,13))
plt.scatter(df.loc[df['Latitude']>1]['Latitude'],df.loc[df['Longitude']<-1]['Longitude'])
plt.show()

# %%
# !pip install folium
import folium
rest_map1=folium.Map([df['Latitude'].values[0],df['Longitude'].values[0]])
for station in df.dropna()['CAMIS'].unique()[:1000]:
    lat=df.loc[df['CAMIS']==station]['Latitude'].values[0]
    lon=df.loc[df['CAMIS']==station]['Longitude'].values[0]
    marker=folium.Marker([lat,lon],popup=str(station))
    marker.add_to(rest_map1)

rest_map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df['Latitude'].value_counts().head()
# Out:
# 0.000000     5497
# 40.648313     975
# 40.759778     542
# 40.774414     393
# 40.733840     361
# Name: Latitude, dtype: int64

# %%
df['Longitude'].value_counts().head()
# Out:
#  0.000000     5497
# -73.788281     975
# -73.829235     542
# -73.877293     393
# -73.871577     361
# Name: Longitude, dtype: int64

# %%
df.isna().sum()
# Out:
# CAMIS                         0
# DBA                         576
# BORO                          0
# BUILDING                    238
# STREET                        4
# ZIPCODE                    5501
# PHONE                        15
# CUISINE DESCRIPTION           0
# INSPECTION DATE               0
# ACTION                     1388
# VIOLATION CODE             5764
# VIOLATION DESCRIPTION      8929
# CRITICAL FLAG              8929
# SCORE                     17211
# GRADE                    190247
# GRADE DATE               192100
# RECORD DATE                   0
# INSPECTION TYPE            1388
# Latitude                    406
# Longitude                   406
# Community Board            5903
# Council District           5903
# Census Tract               5903
# BIN                        7498
# BBL                         406
# NTA                        5903
# dtype: int64

# %%
[df['Latitude'].values[0],df['Longitude'].values[0]]
# Out:
# [40.687078231694, -73.975682771741]

# %%
df.BORO.value_counts()
# Out:
# Manhattan        152431
# Brooklyn          98108
# Queens            87830
# Bronx             34821
# Staten Island     13101
# 0                   112
# Name: BORO, dtype: int64

# %%
sorted(df['INSPECTION DATE'].unique())
# Out:
# [numpy.datetime64('1900-01-01T00:00:00.000000000'),
#  numpy.datetime64('2013-06-07T00:00:00.000000000'),
#  numpy.datetime64('2013-10-22T00:00:00.000000000'),
#  numpy.datetime64('2014-03-06T00:00:00.000000000'),
#  numpy.datetime64('2014-04-21T00:00:00.000000000'),
#  numpy.datetime64('2014-09-13T00:00:00.000000000'),
#  numpy.datetime64('2014-10-30T00:00:00.000000000'),
#  numpy.datetime64('2015-01-05T00:00:00.000000000'),
#  numpy.datetime64('2015-02-11T00:00:00.000000000'),
#  numpy.datetime64('2015-03-30T00:00:00.000000000'),
#  numpy.datetime64('2015-05-02T00:00:00.000000000'),
#  numpy.datetime64('2015-05-08T00:00:00.000000000'),
#  numpy.datetime64('2015-05-09T00:00:00.000000000'),
#  numpy.datetime64('2015-06-23T00:00:00.000000000'),
#  numpy.datetime64('2015-07-01T00:00:00.000000000'),
#  numpy.datetime64('2015-07-06T00:00:00.000000000'),
#  numpy.datetime64('2015-07-24T00:00:00.000000000'),
#  numpy.datetime64('2015-07-27T00:00:00.000000000'),
# ...

# %%
print(df.loc[df['SCORE']==df['SCORE'].max()].iloc[0])
# Out:
# CAMIS                                                             50046375
# DBA                                                           ICHIBA RAMEN
# BORO                                                             Manhattan
# BUILDING                                                               125
# STREET                                                       UNIVERSITY PL
# ZIPCODE                                                              10003
# PHONE                                                           2127772495
# CUISINE DESCRIPTION                                               Japanese
# INSPECTION DATE                                        2019-04-25 00:00:00
# ACTION                   Establishment Closed by DOHMH.  Violations wer...
# VIOLATION CODE                                                         04L
# VIOLATION DESCRIPTION    Evidence of mice or live mice present in facil...
# ...

# %%
time=df['INSPECTION DATE'].dt.round('30d')

# %%
time.value_counts().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa09619fdc5c> in <module>()
# ----> 1 time.value_counts().plot()
#
# NameError: name 'time' is not defined

# %%
df.loc[df['ACTION']]

# %%
url = 'https://raw.githubusercontent.com/python-visualization/folium/master/examples/data'
state_geo = f'{url}/us-states.json'
state_unemployment = f'{url}/US_Unemployment_Oct2012.csv'
state_data = pd.read_csv(state_unemployment)

m = folium.Map(location=[48, -102], zoom_start=3)

folium.Choropleth(
    geo_data=state_geo,
    name='choropleth',
    data=state_data,
    columns=['State', 'Unemployment'],
    key_on='feature.id',
    fill_color='YlGn',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Unemployment Rate (%)'
).add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
